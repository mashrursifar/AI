# %%
# nn.Convo2d(inn_channels, out_channels, kernel_size, stride, padding)
'''
in_channels = )n
black & white = 1
color RGB = 4


out_channels
each output channerl = 1 pattern detector

kernel_size = how big  a batch of the image filter will be shown

'''
